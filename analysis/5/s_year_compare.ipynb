# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\USER'

# %%
stats = pd.read_csv('C:\\Users\\USER\\Desktop\\DSPAT2\\MentalHealth\\Age-standardized suicide rates.csv')

# %%
nRowsRead = 1000
stats.dataframeName = 'Age-standardized suicide rates.csv'
nRow, nCol = stats.shape
print(f' There are {nRow} rows and {nCol} colums')
# Out:
#  There are 549 rows and 6 colums

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']= 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
vis1 = sns.distplot(stats["2016"],[""])
#vis2 = sns.distplot(stats["2015"])
#k1 = sns.kdeplot()

# %%
vis2 = sns.distplot(stats["2015"])

# %%
vis3 = sns.distplot(stats["2010"])

# %%
vis4 = sns.distplot(stats["2000"])

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2, 2, figsize=(15,15))
vis1 = sns.distplot(stats["2016"],ax=axes[0,0])
vis3 = sns.distplot(stats["2015"],ax=axes[0,1])
vis3 = sns.distplot(stats["2010"],ax=axes[1,0])
vis4 = sns.distplot(stats["2000"],ax=axes[1,1])
