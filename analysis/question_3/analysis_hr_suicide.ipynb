# %%
import pandas as pd

df= pd.read_csv('C:\\Users\\USER\\Desktop\\DSPAT2\\MentalHealth\\Human Resources.csv')

# %%
df.head()
# Out:
#                Country  Year  Psychiatrists  Nurses  Social_workers  \
# 0          Afghanistan  2016          0.231   0.098             NaN
# 1              Albania  2016          1.471   6.876           1.060
# 2               Angola  2016          0.057   0.660           0.022
# 3  Antigua and Barbuda  2016          1.001   7.005           4.003
# 4            Argentina  2016         21.705     NaN             NaN
#
#    Psychologists
# 0          0.296
# 1          1.231
# 2          0.179
# 3            NaN
# 4        222.572

# %%
df.Country = df.Country.astype('category')

# %%
df.Year = df.Year.astype('category')

# %%
df.describe()
# Out:
#        Psychiatrists      Nurses  Social_workers  Psychologists
# count     104.000000   91.000000       68.000000      84.000000
# mean        4.340519   12.122934        4.832632      10.415345
# std         7.645392   22.869974       16.902273      31.451687
# min         0.007000    0.000000        0.006000       0.000000
# 25%         0.219750    0.793500        0.066500       0.236750
# 50%         1.231000    4.199000        0.375500       1.139000
# 75%         4.559500   10.952500        1.351250       5.150250
# max        48.040000  150.251000      102.592000     222.572000

# %%
vis1 = sns.lmplot(data=df, x='Psychiatrists', y='Nurses',size=10,scatter_kws={"s":200})

# %%
# filtering the Country where Psychiatrists & Nurses value is less than 1

df[(df.Psychiatrists < 1.0) & (df.Nurses < 1.0)]
# Out:
#            Country  Year  Psychiatrists  Nurses  Social_workers  Psychologists
# 0      Afghanistan  2016          0.231   0.098             NaN          0.296
# 2           Angola  2016          0.057   0.660           0.022          0.179
# 7       Bangladesh  2016          0.130   0.873             NaN          0.124
# 10          Bhutan  2016          0.508   0.127             NaN            NaN
# 15    Burkina Faso  2016          0.039   0.635           0.011          0.022
# 16        Cambodia  2016          0.387   0.277             NaN          7.089
# 17            Chad  2016          0.007   0.021           0.007            NaN
# 20           Congo  2016          0.080   0.500           0.020          0.020
# 23   Côte d'Ivoire  2016          0.130   0.381             NaN            NaN
# 27         Ecuador  2016          0.458   0.056           0.019          7.662
# 33           Gabon  2016          0.259   0.518           0.104          0.777
# ...

# %%
df1 =df[(df.Psychiatrists < 1.0) & (df.Nurses < 1.0)]

# %%
df1.head()
# Out:
#          Country  Year  Psychiatrists  Nurses  Social_workers  Psychologists
# 0    Afghanistan  2016          0.231   0.098             NaN          0.296
# 2         Angola  2016          0.057   0.660           0.022          0.179
# 7     Bangladesh  2016          0.130   0.873             NaN          0.124
# 10        Bhutan  2016          0.508   0.127             NaN            NaN
# 15  Burkina Faso  2016          0.039   0.635           0.011          0.022

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize']= 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
vis2=sns.distplot(df1["Psychiatrists"],bins=30)

# %%
vis3=sns.distplot(df1["Nurses"],bins=30)

# %%
vis4=sns.scatterplot(data=df1,x='Psychiatrists',y='Nurses', hue='Country')
