# %%
import pandas as pd

crude = pd.read_csv('C:\\Users\\USER\\Desktop\\DSPAT2\\MentalHealth\\Crude suicide rates.csv')

# %%
crude.Country = crude.Country.astype('category')

# %%
crude.Sex = crude.Sex.astype('category')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']= 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
#g = sns.FacetGrid(crude, row='Country', col='Sex')

#kws =dict(s=50, linewidth=0.5, edgecolor='black')
#g = g.map(plt.scatter,'80_above' **kws)
#g.set(xlim(0,100),ylim=(0,100))
#for ax in g.axes.flat:
    #ax.plot((0,100),(0,100), c="gray", ls="--")

# %%
crude.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    549 non-null    category
#  1   Sex        549 non-null    category
#  2    80_above  549 non-null    float64
#  3    70to79    549 non-null    float64
#  4    60to69    549 non-null    float64
#  5    50to59    549 non-null    float64
#  6    40to49    549 non-null    float64
#  7    30to39    549 non-null    float64
#  8    20to29    549 non-null    float64
#  9    10to19    549 non-null    float64
# dtypes: category(2), float64(8)
# memory usage: 42.6 KB

# %%
z = sns.boxplot(data=crude, x='Sex', y=' 80_above')

# %%
z1 = sns.boxplot(data=crude, x='Sex', y= ' 70to79')

# %%
z2 = sns.boxplot(data=crude, x='Sex', y=' 60to69 ')

# %%
z3 = sns.boxplot(data=crude, x='Sex', y=' 50to59 ')

# %%
z4 = sns.boxplot(data=crude, x='Sex', y=' 40to49')

# %%
z5 = sns.boxplot(data=crude, x='Sex', y=' 30to39')

# %%
z6 = sns.boxplot(data=crude, x='Sex', y=' 20to29')

# %%
z7 = sns.boxplot(data=crude, x='Sex', y=' 10to19')

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2, 4, figsize=(15,15))
#vis1 = sns.distplot(stats["2016"],ax=axes[0,0])

z = sns.boxplot(data=crude, x='Sex', y=' 80_above', ax=axes[0,0])
z1 = sns.boxplot(data=crude, x='Sex', y= ' 70to79', ax=axes[0,1])
z2 = sns.boxplot(data=crude, x='Sex', y=' 60to69 ', ax=axes[0,2])
z3 = sns.boxplot(data=crude, x='Sex', y=' 50to59 ', ax=axes[0,3])
z4 = sns.boxplot(data=crude, x='Sex', y=' 40to49', ax=axes[1,0])
z5 = sns.boxplot(data=crude, x='Sex', y=' 30to39', ax=axes[1,1])
z6 = sns.boxplot(data=crude, x='Sex', y=' 20to29', ax=axes[1,2])
z7 = sns.boxplot(data=crude, x='Sex', y=' 10to19', ax=axes[1,3])
